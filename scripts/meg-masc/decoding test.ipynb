# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df = pd.read_csv("/home/jgauthie/om2/others/meg-masc/decoding_results.csv", index_col=0)
df
# Out:
#           score  time     label     n  subject  contrast
# 0      0.034087 -0.20  t0_s0_h0   327        1  wordfreq
# 1      0.011803 -0.19  t0_s0_h0   327        1  wordfreq
# 2     -0.010809 -0.18  t0_s0_h0   327        1  wordfreq
# 3     -0.033500 -0.17  t0_s0_h0   327        1  wordfreq
# 4     -0.004466 -0.16  t0_s0_h0   327        1  wordfreq
# ...         ...   ...       ...   ...      ...       ...
# 22999  0.034356  0.56  t3_s1_h1  5272       11    voiced
# 23000  0.017558  0.57  t3_s1_h1  5272       11    voiced
# 23001  0.005743  0.58  t3_s1_h1  5272       11    voiced
# 23002 -0.005189  0.59  t3_s1_h1  5272       11    voiced
# 23003 -0.001745  0.60  t3_s1_h1  5272       11    voiced
#
# [23004 rows x 6 columns]

# %%
df["task"] = df.label.str.extract(r"t(\d+)").astype(int)

# %%
g = sns.FacetGrid(data=df, col="contrast", height=7)
g.map(sns.lineplot, "time", "score", "subject")
