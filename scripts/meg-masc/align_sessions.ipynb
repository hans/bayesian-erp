# %%
import logging
from pprint import pprint

import pandas as pd
import numpy as np

# %%
presentations = [
    {"key": {"subject": "01", "session": 0, "story_name": "lw1"},
     "sound": "lw1.01.0.sound.csv",
     "word": "lw1.01.0.word.csv",
     "phoneme": "lw1.01.0.phoneme.csv"},
    {"key": {"subject": "02", "session": 0, "story_name": "lw1"},
     "sound": "lw1.02.0.sound.csv",
     "word": "lw1.02.0.word.csv",
     "phoneme": "lw1.02.0.phoneme.csv"},
    {"key": {"subject": "01", "session": 0, "story_name": "cable_spool_fort"},
     "sound": "cable_spool_fort.01.0.sound.csv",
     "word": "cable_spool_fort.01.0.word.csv",
     "phoneme": "cable_spool_fort.01.0.phoneme.csv"},
]
output_path = "session_alignment.csv"

# %%
def load_presentation(presentation_dict):
    ret = {}
    recording_key = presentation_dict.pop("key")
    for df_key, path in presentation_dict.items():
        ret[df_key] = pd.read_csv(path, index_col=0).assign(**recording_key)
    return ret

# %%
all_presentations = [load_presentation(presentations_i) for presentations_i in presentations]
# transpose
all_presentations = {key: pd.concat([p_i[key] for p_i in all_presentations])
                     for key in all_presentations[0].keys()}

# %%
# Fix typo?
# in other reprs paths are denoted as e.g. stimuli/audio/lw1_0.wav
# but here we see stimuli/audio/lw1_0.0.wav
all_presentations["sound"]["sound"] = all_presentations["sound"].sound.str.replace(".0.wav", ".wav", regex=False)
all_presentations["sound"]
# Out:
#    index subject             story  story_uid  sound_id   kind  \
# 0    5.0      01               lw1        0.0       0.0  sound
# 1    7.0      01               lw1        0.0       1.0  sound
# 2    9.0      01               lw1        0.0       2.0  sound
# 3   11.0      01               lw1        0.0       3.0  sound
# 0    5.0      02               lw1        0.0       0.0  sound
# 1    7.0      02               lw1        0.0       1.0  sound
# 2    9.0      02               lw1        0.0       2.0  sound
# 3   11.0      02               lw1        0.0       3.0  sound
# 0   14.0      01  cable_spool_fort        1.0       0.0  sound
# 1   16.0      01  cable_spool_fort        1.0       1.0  sound
# 2   18.0      01  cable_spool_fort        1.0       2.0  sound
# 3   20.0      01  cable_spool_fort        1.0       3.0  sound
# 4   22.0      01  cable_spool_fort        1.0       4.0  sound
# 5   24.0      01  cable_spool_fort        1.0       5.0  sound
#
#                       meg_file  start                                 sound  \
# 0  A0167_MASC_1_16Mar17_01.con    0.0               stimuli/audio/lw1_0.wav
# 1  A0167_MASC_1_16Mar17_01.con    0.0               stimuli/audio/lw1_1.wav
# 2  A0167_MASC_1_16Mar17_01.con    0.0               stimuli/audio/lw1_2.wav
# 3  A0167_MASC_1_16Mar17_01.con    0.0               stimuli/audio/lw1_3.wav
# 0  A0168_MASC_1_25Mar17_01.con    0.0               stimuli/audio/lw1_0.wav
# 1  A0168_MASC_1_25Mar17_01.con    0.0               stimuli/audio/lw1_1.wav
# 2  A0168_MASC_1_25Mar17_01.con    0.0               stimuli/audio/lw1_2.wav
# 3  A0168_MASC_1_25Mar17_01.con    0.0               stimuli/audio/lw1_3.wav
# 0  A0167_MASC_2_16Mar17_01.con    0.0  stimuli/audio/cable_spool_fort_0.wav
# 1  A0167_MASC_2_16Mar17_01.con    0.0  stimuli/audio/cable_spool_fort_1.wav
# 2  A0167_MASC_2_16Mar17_01.con    0.0  stimuli/audio/cable_spool_fort_2.wav
# 3  A0167_MASC_2_16Mar17_01.con    0.0  stimuli/audio/cable_spool_fort_3.wav
# 4  A0167_MASC_2_16Mar17_01.con    0.0  stimuli/audio/cable_spool_fort_4.wav
# 5  A0167_MASC_2_16Mar17_01.con    0.0  stimuli/audio/cable_spool_fort_5.wav
#
#      onset  duration  value  sample  session        story_name
# 0   23.506       0.0      2   23506        0               lw1
# 1  127.185       0.0      3  127185        0               lw1
# 2  210.048       0.0      4  210048        0               lw1
# 3  311.027       0.0      1  311027        0               lw1
# 0   18.389       0.0      2   18389        0               lw1
# 1  121.868       0.0      3  121868        0               lw1
# 2  207.648       0.0      4  207648        0               lw1
# 3  306.693       0.0      1  306693        0               lw1
# 0    8.245       0.0      1    8245        0  cable_spool_fort
# 1  114.957       0.0      2  114957        0  cable_spool_fort
# 2  257.717       0.0      3  257717        0  cable_spool_fort
# 3  402.810       0.0      4  402810        0  cable_spool_fort
# 4  517.955       0.0      5  517955        0  cable_spool_fort
# 5  646.766       0.0      6  646766        0  cable_spool_fort

# %%
all_sounds = all_presentations["sound"].groupby(["subject", "session"]) \
    .apply(lambda xs: sorted(xs.groupby(["story_name", "sound_id"]).groups.keys())).tolist()

pprint(all_sounds[0])
for sounds_i in all_sounds[1:]:
    if set(sounds_i) != set(all_sounds[0]):
        logging.warning("Some subject--sessions have different amounds of sounds")
# Out:
# WARNING:root:Some subject--sessions have different amounds of sounds
# [('cable_spool_fort', 0.0),
#  ('cable_spool_fort', 1.0),
#  ('cable_spool_fort', 2.0),
#  ('cable_spool_fort', 3.0),
#  ('cable_spool_fort', 4.0),
#  ('cable_spool_fort', 5.0),
#  ('lw1', 0.0),
#  ('lw1', 1.0),
#  ('lw1', 2.0),
#  ('lw1', 3.0)]

# %%
# Compute sound start points
index_key = ["subject", "session", "story_name", "sound_id", "sound"]
presentation_onsets = all_presentations["sound"][index_key + ["onset"]].set_index(index_key)
presentation_onsets
# Out:
#                                                                                   onset
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                23.506
#                                  1.0      stimuli/audio/lw1_1.wav               127.185
#                                  2.0      stimuli/audio/lw1_2.wav               210.048
#                                  3.0      stimuli/audio/lw1_3.wav               311.027
# 02      0       lw1              0.0      stimuli/audio/lw1_0.wav                18.389
#                                  1.0      stimuli/audio/lw1_1.wav               121.868
#                                  2.0      stimuli/audio/lw1_2.wav               207.648
#                                  3.0      stimuli/audio/lw1_3.wav               306.693
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav    8.245
#                                  1.0      stimuli/audio/cable_spool_fort_1.wav  114.957
#                                  2.0      stimuli/audio/cable_spool_fort_2.wav  257.717
#                                  3.0      stimuli/audio/cable_spool_fort_3.wav  402.810
#                                  4.0      stimuli/audio/cable_spool_fort_4.wav  517.955
#                                  5.0      stimuli/audio/cable_spool_fort_5.wav  646.766

# %% [markdown]
# ## Check words

# %%
w = all_presentations["word"].set_index(index_key)
w["onset_sound"] = presentation_onsets
w["onset_baselined"] = (w.onset - w["onset_sound"]).round(4)
w.sort_index()
# Out:
#                                                                                            story  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_0.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_0.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_0.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_0.wav  cable_spool_fort
# ...                                                                                          ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                            lw1
#                                           stimuli/audio/lw1_3.wav                            lw1
#                                           stimuli/audio/lw1_3.wav                            lw1
#                                           stimuli/audio/lw1_3.wav                            lw1
#                                           stimuli/audio/lw1_3.wav                            lw1
#
#                                                                                 story_uid  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav        1.0
#                                           stimuli/audio/cable_spool_fort_0.wav        1.0
#                                           stimuli/audio/cable_spool_fort_0.wav        1.0
#                                           stimuli/audio/cable_spool_fort_0.wav        1.0
#                                           stimuli/audio/cable_spool_fort_0.wav        1.0
# ...                                                                                   ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                     0.0
#                                           stimuli/audio/lw1_3.wav                     0.0
#                                           stimuli/audio/lw1_3.wav                     0.0
#                                           stimuli/audio/lw1_3.wav                     0.0
#                                           stimuli/audio/lw1_3.wav                     0.0
#
#                                                                                 kind  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav  word
#                                           stimuli/audio/cable_spool_fort_0.wav  word
#                                           stimuli/audio/cable_spool_fort_0.wav  word
#                                           stimuli/audio/cable_spool_fort_0.wav  word
#                                           stimuli/audio/cable_spool_fort_0.wav  word
# ...                                                                              ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav               word
#                                           stimuli/audio/lw1_3.wav               word
#                                           stimuli/audio/lw1_3.wav               word
#                                           stimuli/audio/lw1_3.wav               word
#                                           stimuli/audio/lw1_3.wav               word
#
#                                                                                                    meg_file  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_0.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_0.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_0.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_0.wav  A0167_MASC_2_16Mar17_01.con
# ...                                                                                                     ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav               A0168_MASC_1_25Mar17_01.con
#                                           stimuli/audio/lw1_3.wav               A0168_MASC_1_25Mar17_01.con
#                                           stimuli/audio/lw1_3.wav               A0168_MASC_1_25Mar17_01.con
#                                           stimuli/audio/lw1_3.wav               A0168_MASC_1_25Mar17_01.con
#                                           stimuli/audio/lw1_3.wav               A0168_MASC_1_25Mar17_01.con
#
#                                                                                     start  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav   0.000000
#                                           stimuli/audio/cable_spool_fort_0.wav   0.130000
#                                           stimuli/audio/cable_spool_fort_0.wav   1.020000
#                                           stimuli/audio/cable_spool_fort_0.wav   1.470000
#                                           stimuli/audio/cable_spool_fort_0.wav   1.700000
# ...                                                                                   ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav               50.070000
#                                           stimuli/audio/lw1_3.wav               50.250000
#                                           stimuli/audio/lw1_3.wav               50.460000
#                                           stimuli/audio/lw1_3.wav               51.179999
#                                           stimuli/audio/lw1_3.wav               51.790000
#
#                                                                                    word  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav      The
#                                           stimuli/audio/cable_spool_fort_0.wav    Cable
#                                           stimuli/audio/cable_spool_fort_0.wav     Fort
#                                           stimuli/audio/cable_spool_fort_0.wav       by
#                                           stimuli/audio/cable_spool_fort_0.wav     Bill
# ...                                                                                 ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                   end
#                                           stimuli/audio/lw1_3.wav                   for
#                                           stimuli/audio/lw1_3.wav               project
#                                           stimuli/audio/lw1_3.wav                   and
#                                           stimuli/audio/lw1_3.wav               species
#
#                                                                                 sequence_id  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav          0.0
#                                           stimuli/audio/cable_spool_fort_0.wav          0.0
#                                           stimuli/audio/cable_spool_fort_0.wav          0.0
#                                           stimuli/audio/cable_spool_fort_0.wav          0.0
#                                           stimuli/audio/cable_spool_fort_0.wav          0.0
# ...                                                                                     ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                      52.0
#                                           stimuli/audio/lw1_3.wav                      52.0
#                                           stimuli/audio/lw1_3.wav                      52.0
#                                           stimuli/audio/lw1_3.wav                      52.0
#                                           stimuli/audio/lw1_3.wav                      52.0
#
#                                                                                condition  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav  sentence
#                                           stimuli/audio/cable_spool_fort_0.wav  sentence
#                                           stimuli/audio/cable_spool_fort_0.wav  sentence
#                                           stimuli/audio/cable_spool_fort_0.wav  sentence
#                                           stimuli/audio/cable_spool_fort_0.wav  sentence
# ...                                                                                  ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav               sentence
#                                           stimuli/audio/lw1_3.wav               sentence
#                                           stimuli/audio/lw1_3.wav               sentence
#                                           stimuli/audio/lw1_3.wav               sentence
#                                           stimuli/audio/lw1_3.wav               sentence
#
#                                                                                 word_index  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav         0.0
#                                           stimuli/audio/cable_spool_fort_0.wav         1.0
#                                           stimuli/audio/cable_spool_fort_0.wav         3.0
#                                           stimuli/audio/cable_spool_fort_0.wav         4.0
#                                           stimuli/audio/cable_spool_fort_0.wav         5.0
# ...                                                                                    ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                     15.0
#                                           stimuli/audio/lw1_3.wav                     16.0
#                                           stimuli/audio/lw1_3.wav                     18.0
#                                           stimuli/audio/lw1_3.wav                     19.0
#                                           stimuli/audio/lw1_3.wav                     22.0
#
#                                                                                 speech_rate  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav        160.0
#                                           stimuli/audio/cable_spool_fort_0.wav        160.0
#                                           stimuli/audio/cable_spool_fort_0.wav        160.0
#                                           stimuli/audio/cable_spool_fort_0.wav        160.0
#                                           stimuli/audio/cable_spool_fort_0.wav        160.0
# ...                                                                                     ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                     205.0
#                                           stimuli/audio/lw1_3.wav                     205.0
#                                           stimuli/audio/lw1_3.wav                     205.0
#                                           stimuli/audio/lw1_3.wav                     205.0
#                                           stimuli/audio/lw1_3.wav                     205.0
#
#                                                                                   voice  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav      Ava
#                                           stimuli/audio/cable_spool_fort_0.wav      Ava
#                                           stimuli/audio/cable_spool_fort_0.wav      Ava
#                                           stimuli/audio/cable_spool_fort_0.wav      Ava
#                                           stimuli/audio/cable_spool_fort_0.wav      Ava
# ...                                                                                 ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav               Allison
#                                           stimuli/audio/lw1_3.wav               Allison
#                                           stimuli/audio/lw1_3.wav               Allison
#                                           stimuli/audio/lw1_3.wav               Allison
#                                           stimuli/audio/lw1_3.wav               Allison
#
#                                                                                 pronounced  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav         1.0
#                                           stimuli/audio/cable_spool_fort_0.wav         1.0
#                                           stimuli/audio/cable_spool_fort_0.wav         1.0
#                                           stimuli/audio/cable_spool_fort_0.wav         1.0
#                                           stimuli/audio/cable_spool_fort_0.wav         1.0
# ...                                                                                    ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                      1.0
#                                           stimuli/audio/lw1_3.wav                      1.0
#                                           stimuli/audio/lw1_3.wav                      1.0
#                                           stimuli/audio/lw1_3.wav                      1.0
#                                           stimuli/audio/lw1_3.wav                      1.0
#
#                                                                                   onset  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav    8.245
#                                           stimuli/audio/cable_spool_fort_0.wav    8.375
#                                           stimuli/audio/cable_spool_fort_0.wav    9.265
#                                           stimuli/audio/cable_spool_fort_0.wav    9.715
#                                           stimuli/audio/cable_spool_fort_0.wav    9.945
# ...                                                                                 ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav               356.763
#                                           stimuli/audio/lw1_3.wav               356.943
#                                           stimuli/audio/lw1_3.wav               357.153
#                                           stimuli/audio/lw1_3.wav               357.873
#                                           stimuli/audio/lw1_3.wav               358.483
#
#                                                                                 duration  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav      0.13
#                                           stimuli/audio/cable_spool_fort_0.wav      0.48
#                                           stimuli/audio/cable_spool_fort_0.wav      0.42
#                                           stimuli/audio/cable_spool_fort_0.wav      0.23
#                                           stimuli/audio/cable_spool_fort_0.wav      0.25
# ...                                                                                  ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                   0.17
#                                           stimuli/audio/lw1_3.wav                   0.14
#                                           stimuli/audio/lw1_3.wav                   0.58
#                                           stimuli/audio/lw1_3.wav                   0.15
#                                           stimuli/audio/lw1_3.wav                   0.34
#
#                                                                                 value  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav    982
#                                           stimuli/audio/cable_spool_fort_0.wav    983
#                                           stimuli/audio/cable_spool_fort_0.wav    984
#                                           stimuli/audio/cable_spool_fort_0.wav    985
#                                           stimuli/audio/cable_spool_fort_0.wav    986
# ...                                                                               ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                3119
#                                           stimuli/audio/lw1_3.wav                3120
#                                           stimuli/audio/lw1_3.wav                3121
#                                           stimuli/audio/lw1_3.wav                3122
#                                           stimuli/audio/lw1_3.wav                3123
#
#                                                                                 sample  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav    8245
#                                           stimuli/audio/cable_spool_fort_0.wav    8375
#                                           stimuli/audio/cable_spool_fort_0.wav    9265
#                                           stimuli/audio/cable_spool_fort_0.wav    9715
#                                           stimuli/audio/cable_spool_fort_0.wav    9945
# ...                                                                                ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav               356763
#                                           stimuli/audio/lw1_3.wav               356943
#                                           stimuli/audio/lw1_3.wav               357153
#                                           stimuli/audio/lw1_3.wav               357873
#                                           stimuli/audio/lw1_3.wav               358483
#
#                                                                                 onset_sound  \
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav        8.245
#                                           stimuli/audio/cable_spool_fort_0.wav        8.245
#                                           stimuli/audio/cable_spool_fort_0.wav        8.245
#                                           stimuli/audio/cable_spool_fort_0.wav        8.245
#                                           stimuli/audio/cable_spool_fort_0.wav        8.245
# ...                                                                                     ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                   306.693
#                                           stimuli/audio/lw1_3.wav                   306.693
#                                           stimuli/audio/lw1_3.wav                   306.693
#                                           stimuli/audio/lw1_3.wav                   306.693
#                                           stimuli/audio/lw1_3.wav                   306.693
#
#                                                                                 onset_baselined
# subject session story_name       sound_id sound
# 01      0       cable_spool_fort 0.0      stimuli/audio/cable_spool_fort_0.wav             0.00
#                                           stimuli/audio/cable_spool_fort_0.wav             0.13
#                                           stimuli/audio/cable_spool_fort_0.wav             1.02
#                                           stimuli/audio/cable_spool_fort_0.wav             1.47
#                                           stimuli/audio/cable_spool_fort_0.wav             1.70
# ...                                                                                         ...
# 02      0       lw1              3.0      stimuli/audio/lw1_3.wav                         50.07
#                                           stimuli/audio/lw1_3.wav                         50.25
#                                           stimuli/audio/lw1_3.wav                         50.46
#                                           stimuli/audio/lw1_3.wav                         51.18
#                                           stimuli/audio/lw1_3.wav                         51.79
#
# [2839 rows x 18 columns]

# %%
# For each word presentation, get number of different onsets relative to sound onset.
# Should be 1 for everything.
num_unique_word_onsets = w.groupby(["story_name", "sequence_id", "word_index", "condition"]).apply(lambda xs: len(set(xs.onset_baselined)))
assert set(num_unique_word_onsets.values) == {1}

# %%
# And there should be N word presentations for a sound played N times.
for sound, sound_presentations in presentation_onsets.groupby("sound"):
    assert set(w.xs(sound, level="sound").groupby("onset_baselined").size()) == {len(sound_presentations)}

# %%
# TODO check that these and the word lists are the same for all subjects/sessions
w.reset_index().set_index(["condition", "subject"]).loc["pseudo_words"].groupby("subject").head(10)
# Out:
#          session story_name  sound_id                    sound story  \
# subject
# 01             0        lw1       3.0  stimuli/audio/lw1_3.wav   lw1
# 02             0        lw1       3.0  stimuli/audio/lw1_3.wav   lw1
#
#          story_uid  kind                     meg_file  start word  ...  \
# subject                                                            ...
# 01             0.0  word  A0167_MASC_1_16Mar17_01.con  33.23   ro  ...
# 02             0.0  word  A0168_MASC_1_25Mar17_01.con  33.23   ro  ...
#
#          word_index  speech_rate    voice pronounced    onset  duration  \
# subject
# 01             20.0        205.0  Allison        1.0  344.257      0.15
# 02             20.0        205.0  Allison        1.0  339.923      0.15
#
#          value  sample  onset_sound  onset_baselined
# subject
# 01        3071  344257      311.027            33.23
# 02        3071  339923      306.693            33.23
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Check phonemes

# %%
p = all_presentations["phoneme"].set_index(index_key)
p["onset_sound"] = presentation_onsets
p["onset_baselined"] = (p.onset - p["onset_sound"]).round(4)
p
# Out:
#                                                                                            story  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                            lw1
#                                           stimuli/audio/lw1_0.wav                            lw1
#                                           stimuli/audio/lw1_0.wav                            lw1
#                                           stimuli/audio/lw1_0.wav                            lw1
#                                           stimuli/audio/lw1_0.wav                            lw1
# ...                                                                                          ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_5.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_5.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_5.wav  cable_spool_fort
#                                           stimuli/audio/cable_spool_fort_5.wav  cable_spool_fort
#
#                                                                                 story_uid  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                     0.0
#                                           stimuli/audio/lw1_0.wav                     0.0
#                                           stimuli/audio/lw1_0.wav                     0.0
#                                           stimuli/audio/lw1_0.wav                     0.0
#                                           stimuli/audio/lw1_0.wav                     0.0
# ...                                                                                   ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav        1.0
#                                           stimuli/audio/cable_spool_fort_5.wav        1.0
#                                           stimuli/audio/cable_spool_fort_5.wav        1.0
#                                           stimuli/audio/cable_spool_fort_5.wav        1.0
#                                           stimuli/audio/cable_spool_fort_5.wav        1.0
#
#                                                                                    kind  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav               phoneme
#                                           stimuli/audio/lw1_0.wav               phoneme
#                                           stimuli/audio/lw1_0.wav               phoneme
#                                           stimuli/audio/lw1_0.wav               phoneme
#                                           stimuli/audio/lw1_0.wav               phoneme
# ...                                                                                 ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  phoneme
#                                           stimuli/audio/cable_spool_fort_5.wav  phoneme
#                                           stimuli/audio/cable_spool_fort_5.wav  phoneme
#                                           stimuli/audio/cable_spool_fort_5.wav  phoneme
#                                           stimuli/audio/cable_spool_fort_5.wav  phoneme
#
#                                                                                                    meg_file  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav               A0167_MASC_1_16Mar17_01.con
#                                           stimuli/audio/lw1_0.wav               A0167_MASC_1_16Mar17_01.con
#                                           stimuli/audio/lw1_0.wav               A0167_MASC_1_16Mar17_01.con
#                                           stimuli/audio/lw1_0.wav               A0167_MASC_1_16Mar17_01.con
#                                           stimuli/audio/lw1_0.wav               A0167_MASC_1_16Mar17_01.con
# ...                                                                                                     ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_5.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_5.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_5.wav  A0167_MASC_2_16Mar17_01.con
#                                           stimuli/audio/cable_spool_fort_5.wav  A0167_MASC_2_16Mar17_01.con
#
#                                                                                     start  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                0.000000
#                                           stimuli/audio/lw1_0.wav                0.080000
#                                           stimuli/audio/lw1_0.wav                0.170000
#                                           stimuli/audio/lw1_0.wav                0.240000
#                                           stimuli/audio/lw1_0.wav                0.310000
# ...                                                                                   ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  53.719999
#                                           stimuli/audio/cable_spool_fort_5.wav  53.789999
#                                           stimuli/audio/cable_spool_fort_5.wav  53.859999
#                                           stimuli/audio/cable_spool_fort_5.wav  53.949999
#                                           stimuli/audio/cable_spool_fort_5.wav  54.089999
#
#                                                                                phoneme  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                  t_B
#                                           stimuli/audio/lw1_0.wav                 eh_I
#                                           stimuli/audio/lw1_0.wav                  r_I
#                                           stimuli/audio/lw1_0.wav                 ah_E
#                                           stimuli/audio/lw1_0.wav                  s_B
# ...                                                                                ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav    ao_B
#                                           stimuli/audio/cable_spool_fort_5.wav     l_E
#                                           stimuli/audio/cable_spool_fort_5.wav     r_B
#                                           stimuli/audio/cable_spool_fort_5.wav    ay_I
#                                           stimuli/audio/cable_spool_fort_5.wav     t_E
#
#                                                                                 sequence_id  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                       0.0
#                                           stimuli/audio/lw1_0.wav                       0.0
#                                           stimuli/audio/lw1_0.wav                       0.0
#                                           stimuli/audio/lw1_0.wav                       0.0
#                                           stimuli/audio/lw1_0.wav                       0.0
# ...                                                                                     ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav        128.0
#                                           stimuli/audio/cable_spool_fort_5.wav        128.0
#                                           stimuli/audio/cable_spool_fort_5.wav        128.0
#                                           stimuli/audio/cable_spool_fort_5.wav        128.0
#                                           stimuli/audio/cable_spool_fort_5.wav        128.0
#
#                                                                                condition  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav               sentence
#                                           stimuli/audio/lw1_0.wav               sentence
#                                           stimuli/audio/lw1_0.wav               sentence
#                                           stimuli/audio/lw1_0.wav               sentence
#                                           stimuli/audio/lw1_0.wav               sentence
# ...                                                                                  ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  sentence
#                                           stimuli/audio/cable_spool_fort_5.wav  sentence
#                                           stimuli/audio/cable_spool_fort_5.wav  sentence
#                                           stimuli/audio/cable_spool_fort_5.wav  sentence
#                                           stimuli/audio/cable_spool_fort_5.wav  sentence
#
#                                                                                 word_index  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                      0.0
#                                           stimuli/audio/lw1_0.wav                      0.0
#                                           stimuli/audio/lw1_0.wav                      0.0
#                                           stimuli/audio/lw1_0.wav                      0.0
#                                           stimuli/audio/lw1_0.wav                      1.0
# ...                                                                                    ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav         2.0
#                                           stimuli/audio/cable_spool_fort_5.wav         2.0
#                                           stimuli/audio/cable_spool_fort_5.wav         3.0
#                                           stimuli/audio/cable_spool_fort_5.wav         3.0
#                                           stimuli/audio/cable_spool_fort_5.wav         3.0
#
#                                                                                 speech_rate  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                     205.0
#                                           stimuli/audio/lw1_0.wav                     205.0
#                                           stimuli/audio/lw1_0.wav                     205.0
#                                           stimuli/audio/lw1_0.wav                     205.0
#                                           stimuli/audio/lw1_0.wav                     205.0
# ...                                                                                     ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav        190.0
#                                           stimuli/audio/cable_spool_fort_5.wav        190.0
#                                           stimuli/audio/cable_spool_fort_5.wav        190.0
#                                           stimuli/audio/cable_spool_fort_5.wav        190.0
#                                           stimuli/audio/cable_spool_fort_5.wav        190.0
#
#                                                                                   voice  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav               Allison
#                                           stimuli/audio/lw1_0.wav               Allison
#                                           stimuli/audio/lw1_0.wav               Allison
#                                           stimuli/audio/lw1_0.wav               Allison
#                                           stimuli/audio/lw1_0.wav               Allison
# ...                                                                                 ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  Allison
#                                           stimuli/audio/cable_spool_fort_5.wav  Allison
#                                           stimuli/audio/cable_spool_fort_5.wav  Allison
#                                           stimuli/audio/cable_spool_fort_5.wav  Allison
#                                           stimuli/audio/cable_spool_fort_5.wav  Allison
#
#                                                                                 pronounced  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                      1.0
#                                           stimuli/audio/lw1_0.wav                      1.0
#                                           stimuli/audio/lw1_0.wav                      1.0
#                                           stimuli/audio/lw1_0.wav                      1.0
#                                           stimuli/audio/lw1_0.wav                      1.0
# ...                                                                                    ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav         1.0
#                                           stimuli/audio/cable_spool_fort_5.wav         1.0
#                                           stimuli/audio/cable_spool_fort_5.wav         1.0
#                                           stimuli/audio/cable_spool_fort_5.wav         1.0
#                                           stimuli/audio/cable_spool_fort_5.wav         1.0
#
#                                                                                   onset  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                23.506
#                                           stimuli/audio/lw1_0.wav                23.586
#                                           stimuli/audio/lw1_0.wav                23.676
#                                           stimuli/audio/lw1_0.wav                23.746
#                                           stimuli/audio/lw1_0.wav                23.816
# ...                                                                                 ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  700.486
#                                           stimuli/audio/cable_spool_fort_5.wav  700.556
#                                           stimuli/audio/cable_spool_fort_5.wav  700.626
#                                           stimuli/audio/cable_spool_fort_5.wav  700.716
#                                           stimuli/audio/cable_spool_fort_5.wav  700.856
#
#                                                                                 duration  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                   0.08
#                                           stimuli/audio/lw1_0.wav                   0.09
#                                           stimuli/audio/lw1_0.wav                   0.07
#                                           stimuli/audio/lw1_0.wav                   0.06
#                                           stimuli/audio/lw1_0.wav                   0.06
# ...                                                                                  ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav      0.07
#                                           stimuli/audio/cable_spool_fort_5.wav      0.07
#                                           stimuli/audio/cable_spool_fort_5.wav      0.09
#                                           stimuli/audio/cable_spool_fort_5.wav      0.14
#                                           stimuli/audio/cable_spool_fort_5.wav      0.20
#
#                                                                                 value  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                   5
#                                           stimuli/audio/lw1_0.wav                   6
#                                           stimuli/audio/lw1_0.wav                   7
#                                           stimuli/audio/lw1_0.wav                   8
#                                           stimuli/audio/lw1_0.wav                   9
# ...                                                                               ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav   6478
#                                           stimuli/audio/cable_spool_fort_5.wav   6479
#                                           stimuli/audio/cable_spool_fort_5.wav   6480
#                                           stimuli/audio/cable_spool_fort_5.wav   6481
#                                           stimuli/audio/cable_spool_fort_5.wav   6482
#
#                                                                                 sample  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                23506
#                                           stimuli/audio/lw1_0.wav                23586
#                                           stimuli/audio/lw1_0.wav                23676
#                                           stimuli/audio/lw1_0.wav                23746
#                                           stimuli/audio/lw1_0.wav                23816
# ...                                                                                ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav  700486
#                                           stimuli/audio/cable_spool_fort_5.wav  700556
#                                           stimuli/audio/cable_spool_fort_5.wav  700626
#                                           stimuli/audio/cable_spool_fort_5.wav  700716
#                                           stimuli/audio/cable_spool_fort_5.wav  700856
#
#                                                                                 onset_sound  \
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                    23.506
#                                           stimuli/audio/lw1_0.wav                    23.506
#                                           stimuli/audio/lw1_0.wav                    23.506
#                                           stimuli/audio/lw1_0.wav                    23.506
#                                           stimuli/audio/lw1_0.wav                    23.506
# ...                                                                                     ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav      646.766
#                                           stimuli/audio/cable_spool_fort_5.wav      646.766
#                                           stimuli/audio/cable_spool_fort_5.wav      646.766
#                                           stimuli/audio/cable_spool_fort_5.wav      646.766
#                                           stimuli/audio/cable_spool_fort_5.wav      646.766
#
#                                                                                 onset_baselined
# subject session story_name       sound_id sound
# 01      0       lw1              0.0      stimuli/audio/lw1_0.wav                          0.00
#                                           stimuli/audio/lw1_0.wav                          0.08
#                                           stimuli/audio/lw1_0.wav                          0.17
#                                           stimuli/audio/lw1_0.wav                          0.24
#                                           stimuli/audio/lw1_0.wav                          0.31
# ...                                                                                         ...
#                 cable_spool_fort 5.0      stimuli/audio/cable_spool_fort_5.wav            53.72
#                                           stimuli/audio/cable_spool_fort_5.wav            53.79
#                                           stimuli/audio/cable_spool_fort_5.wav            53.86
#                                           stimuli/audio/cable_spool_fort_5.wav            53.95
#                                           stimuli/audio/cable_spool_fort_5.wav            54.09
#
# [10037 rows x 18 columns]

# %%
# For each phoneme presentation, get number of different onsets relative to sound onset.
# Should be 1 for everything.
num_unique_phoneme_onsets = p.groupby(["story_name", "sequence_id", "word_index", "condition", "value"]).apply(lambda xs: len(set(xs.onset_baselined)))
assert set(num_unique_phoneme_onsets.values) == {1}

# %%
# And there should be N word presentations for a sound played N times.
for sound, sound_presentations in presentation_onsets.groupby("sound"):
    assert set(p.xs(sound, level="sound").groupby("onset_baselined").size()) == {len(sound_presentations)}

# %% [markdown]
# ## Build and save a canonical alignment

# %%
# Use first session as the canonical alignment. Arbitrary.
_, sound_sequence = next(iter(all_presentations["sound"].groupby(["subject", "session"])))
canonical_sound_sequence = sound_sequence[["story_name", "sound_id"]].drop_duplicates()

# %%
presentation_onsets = pd.merge(
    canonical_sound_sequence,
    all_presentations["sound"][["story_name", "sound_id", "subject", "session", "onset"]],
    how="left")

presentation_onsets
# Out:
#           story_name  sound_id subject  session    onset
# 0                lw1       0.0      01        0   23.506
# 1                lw1       0.0      02        0   18.389
# 2                lw1       1.0      01        0  127.185
# 3                lw1       1.0      02        0  121.868
# 4                lw1       2.0      01        0  210.048
# 5                lw1       2.0      02        0  207.648
# 6                lw1       3.0      01        0  311.027
# 7                lw1       3.0      02        0  306.693
# 8   cable_spool_fort       0.0      01        0    8.245
# 9   cable_spool_fort       1.0      01        0  114.957
# 10  cable_spool_fort       2.0      01        0  257.717
# 11  cable_spool_fort       3.0      01        0  402.810
# 12  cable_spool_fort       4.0      01        0  517.955
# 13  cable_spool_fort       5.0      01        0  646.766

# %%
presentation_onsets.to_csv(output_path)
