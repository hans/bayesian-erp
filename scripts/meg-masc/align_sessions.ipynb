# %%
import pandas as pd
import numpy as np

# %%
presentations = [
    {"key": {"subject": "01", "session": 0, "story_name": "lw1"},
     "sound": "lw1.01.0.sound.csv",
     "word": "lw1.01.0.word.csv",
     "phoneme": "lw1.01.0.phoneme.csv"},
    {"key": {"subject": "02", "session": 0, "story_name": "lw1"},
     "sound": "lw1.02.0.sound.csv",
     "word": "lw1.02.0.word.csv",
     "phoneme": "lw1.02.0.phoneme.csv"},
]
output_path = "session_alignment.csv"

# %%
def load_presentation(presentation_dict):
    ret = {}
    recording_key = presentation_dict.pop("key")
    for df_key, path in presentation_dict.items():
        ret[df_key] = pd.read_csv(path, index_col=0).assign(**recording_key)
    return ret

# %%
all_presentations = [load_presentation(presentations_i) for presentations_i in presentations]
# transpose
all_presentations = {key: pd.concat([p_i[key] for p_i in all_presentations])
                     for key in all_presentations[0].keys()}
all_presentations
# Out:
# {'sound':    index subject story  story_uid  sound_id   kind  \
#  0    5.0      01   lw1        0.0       0.0  sound
#  1    7.0      01   lw1        0.0       1.0  sound
#  2    9.0      01   lw1        0.0       2.0  sound
#  3   11.0      01   lw1        0.0       3.0  sound
#  0    5.0      02   lw1        0.0       0.0  sound
#  1    7.0      02   lw1        0.0       1.0  sound
#  2    9.0      02   lw1        0.0       2.0  sound
#  3   11.0      02   lw1        0.0       3.0  sound
#
#                        meg_file  start                      sound    onset  \
#  0  A0167_MASC_1_16Mar17_01.con    0.0  stimuli/audio/lw1_0.0.wav   23.506
#  1  A0167_MASC_1_16Mar17_01.con    0.0  stimuli/audio/lw1_1.0.wav  127.185
#  2  A0167_MASC_1_16Mar17_01.con    0.0  stimuli/audio/lw1_2.0.wav  210.048
#  3  A0167_MASC_1_16Mar17_01.con    0.0  stimuli/audio/lw1_3.0.wav  311.027
#  0  A0168_MASC_1_25Mar17_01.con    0.0  stimuli/audio/lw1_0.0.wav   18.389
#  1  A0168_MASC_1_25Mar17_01.con    0.0  stimuli/audio/lw1_1.0.wav  121.868
#  2  A0168_MASC_1_25Mar17_01.con    0.0  stimuli/audio/lw1_2.0.wav  207.648
#  3  A0168_MASC_1_25Mar17_01.con    0.0  stimuli/audio/lw1_3.0.wav  306.693
#
#     duration  value  sample  session story_name
#  0       0.0      2   23506        0        lw1
#  1       0.0      3  127185        0        lw1
#  2       0.0      4  210048        0        lw1
#  3       0.0      1  311027        0        lw1
#  0       0.0      2   18389        0        lw1
#  1       0.0      3  121868        0        lw1
#  2       0.0      4  207648        0        lw1
#  3       0.0      1  306693        0        lw1  ,
#  'word':     story  story_uid  sound_id  kind                     meg_file      start  \
#  0     lw1        0.0       0.0  word  A0167_MASC_1_16Mar17_01.con   0.000000
#  1     lw1        0.0       0.0  word  A0167_MASC_1_16Mar17_01.con   0.310000
#  2     lw1        0.0       0.0  word  A0167_MASC_1_16Mar17_01.con   0.550000
#  3     lw1        0.0       0.0  word  A0167_MASC_1_16Mar17_01.con   1.080000
#  4     lw1        0.0       0.0  word  A0167_MASC_1_16Mar17_01.con   1.630000
#  ..    ...        ...       ...   ...                          ...        ...
#  663   lw1        0.0       3.0  word  A0168_MASC_1_25Mar17_01.con  50.070000
#  664   lw1        0.0       3.0  word  A0168_MASC_1_25Mar17_01.con  50.250000
#  665   lw1        0.0       3.0  word  A0168_MASC_1_25Mar17_01.con  50.460000
#  666   lw1        0.0       3.0  word  A0168_MASC_1_25Mar17_01.con  51.179999
#  667   lw1        0.0       3.0  word  A0168_MASC_1_25Mar17_01.con  51.790000
#
#                         sound     word  sequence_id condition  ...  \
#  0    stimuli/audio/lw1_0.wav     Tara          0.0  sentence  ...
#  1    stimuli/audio/lw1_0.wav    stood          0.0  sentence  ...
#  2    stimuli/audio/lw1_0.wav    stock          0.0  sentence  ...
#  3    stimuli/audio/lw1_0.wav    still          0.0  sentence  ...
#  4    stimuli/audio/lw1_0.wav  waiting          0.0  sentence  ...
#  ..                       ...      ...          ...       ...  ...
#  663  stimuli/audio/lw1_3.wav      end         52.0  sentence  ...
#  664  stimuli/audio/lw1_3.wav      for         52.0  sentence  ...
#  665  stimuli/audio/lw1_3.wav  project         52.0  sentence  ...
#  666  stimuli/audio/lw1_3.wav      and         52.0  sentence  ...
#  667  stimuli/audio/lw1_3.wav  species         52.0  sentence  ...
#
#       speech_rate    voice pronounced    onset  duration  value  sample  \
#  0          205.0  Allison        1.0   23.506      0.30    697   23506
#  1          205.0  Allison        1.0   23.816      0.24    698   23816
#  2          205.0  Allison        1.0   24.056      0.37    699   24056
#  3          205.0  Allison        1.0   24.586      0.40    700   24586
#  4          205.0  Allison        1.0   25.136      0.41    701   25136
#  ..           ...      ...        ...      ...       ...    ...     ...
#  663        205.0  Allison        1.0  356.763      0.17   3119  356763
#  664        205.0  Allison        1.0  356.943      0.14   3120  356943
#  665        205.0  Allison        1.0  357.153      0.58   3121  357153
#  666        205.0  Allison        1.0  357.873      0.15   3122  357873
#  667        205.0  Allison        1.0  358.483      0.34   3123  358483
#
#       subject session  story_name
#  0         01       0         lw1
#  1         01       0         lw1
#  2         01       0         lw1
#  3         01       0         lw1
#  4         01       0         lw1
#  ..       ...     ...         ...
#  663       02       0         lw1
#  664       02       0         lw1
#  665       02       0         lw1
#  666       02       0         lw1
#  667       02       0         lw1
#
#  [1336 rows x 21 columns],
#  'phoneme':      story  story_uid  sound_id     kind                     meg_file  start  \
#  0      lw1        0.0       0.0  phoneme  A0167_MASC_1_16Mar17_01.con   0.00
#  1      lw1        0.0       0.0  phoneme  A0167_MASC_1_16Mar17_01.con   0.08
#  2      lw1        0.0       0.0  phoneme  A0167_MASC_1_16Mar17_01.con   0.17
#  3      lw1        0.0       0.0  phoneme  A0167_MASC_1_16Mar17_01.con   0.24
#  4      lw1        0.0       0.0  phoneme  A0167_MASC_1_16Mar17_01.con   0.31
#  ...    ...        ...       ...      ...                          ...    ...
#  2457   lw1        0.0       3.0  phoneme  A0168_MASC_1_25Mar17_01.con  51.85
#  2458   lw1        0.0       3.0  phoneme  A0168_MASC_1_25Mar17_01.con  51.94
#  2459   lw1        0.0       3.0  phoneme  A0168_MASC_1_25Mar17_01.con  52.03
#  2460   lw1        0.0       3.0  phoneme  A0168_MASC_1_25Mar17_01.con  52.11
#  2461   lw1        0.0       3.0  phoneme  A0168_MASC_1_25Mar17_01.con  52.12
#
#                          sound phoneme  sequence_id condition  ...  \
#  0     stimuli/audio/lw1_0.wav     t_B          0.0  sentence  ...
#  1     stimuli/audio/lw1_0.wav    eh_I          0.0  sentence  ...
#  2     stimuli/audio/lw1_0.wav     r_I          0.0  sentence  ...
#  3     stimuli/audio/lw1_0.wav    ah_E          0.0  sentence  ...
#  4     stimuli/audio/lw1_0.wav     s_B          0.0  sentence  ...
#  ...                       ...     ...          ...       ...  ...
#  2457  stimuli/audio/lw1_3.wav     p_I         52.0  sentence  ...
#  2458  stimuli/audio/lw1_3.wav    iy_I         52.0  sentence  ...
#  2459  stimuli/audio/lw1_3.wav    sh_I         52.0  sentence  ...
#  2460  stimuli/audio/lw1_3.wav    iy_I         52.0  sentence  ...
#  2461  stimuli/audio/lw1_3.wav     z_E         52.0  sentence  ...
#
#        speech_rate    voice pronounced    onset  duration  value  sample  \
#  0           205.0  Allison        1.0   23.506      0.08      5   23506
#  1           205.0  Allison        1.0   23.586      0.09      6   23586
#  2           205.0  Allison        1.0   23.676      0.07      7   23676
#  3           205.0  Allison        1.0   23.746      0.06      8   23746
#  4           205.0  Allison        1.0   23.816      0.06      9   23816
#  ...           ...      ...        ...      ...       ...    ...     ...
#  2457        205.0  Allison        1.0  358.543      0.09   2962  358543
#  2458        205.0  Allison        1.0  358.633      0.09   2963  358633
#  2459        205.0  Allison        1.0  358.723      0.08   2964  358723
#  2460        205.0  Allison        1.0  358.803      0.01   2965  358803
#  2461        205.0  Allison        1.0  358.813      0.01   2966  358813
#
#        subject session  story_name
#  0          01       0         lw1
#  1          01       0         lw1
#  2          01       0         lw1
#  3          01       0         lw1
#  4          01       0         lw1
#  ...       ...     ...         ...
#  2457       02       0         lw1
#  2458       02       0         lw1
#  2459       02       0         lw1
#  2460       02       0         lw1
#  2461       02       0         lw1
#
#  [4924 rows x 21 columns]}

# %%
all_sounds = all_presentations["sound"].groupby("subject") \
    .apply(lambda xs: sorted(xs.groupby(["story_name", "sound_id"]).groups.keys())).tolist()
for sounds_i in all_sounds[1:]:
    assert sounds_i == all_sounds[0]

# %%
# Compute sound start points
index_key = ["subject", "session", "story_name", "sound_id"]
presentation_onsets = all_presentations["sound"][index_key + ["onset"]].set_index(index_key)
presentation_onsets
# Out:
#                                        onset
# subject session story_name sound_id
# 01      0       lw1        0.0        23.506
#                            1.0       127.185
#                            2.0       210.048
#                            3.0       311.027
# 02      0       lw1        0.0        18.389
#                            1.0       121.868
#                            2.0       207.648
#                            3.0       306.693

# %% [markdown]
# ## Check words

# %%
w = all_presentations["word"].set_index(index_key)
w["onset_sound"] = presentation_onsets
w["onset_baselined"] = (w.onset - w["onset_sound"]).round(4)
w
# Out:
#                                     story  story_uid  kind  \
# subject session story_name sound_id
# 01      0       lw1        0.0        lw1        0.0  word
#                            0.0        lw1        0.0  word
#                            0.0        lw1        0.0  word
#                            0.0        lw1        0.0  word
#                            0.0        lw1        0.0  word
# ...                                   ...        ...   ...
# 02      0       lw1        3.0        lw1        0.0  word
#                            3.0        lw1        0.0  word
#                            3.0        lw1        0.0  word
#                            3.0        lw1        0.0  word
#                            3.0        lw1        0.0  word
#
#                                                         meg_file      start  \
# subject session story_name sound_id
# 01      0       lw1        0.0       A0167_MASC_1_16Mar17_01.con   0.000000
#                            0.0       A0167_MASC_1_16Mar17_01.con   0.310000
#                            0.0       A0167_MASC_1_16Mar17_01.con   0.550000
#                            0.0       A0167_MASC_1_16Mar17_01.con   1.080000
#                            0.0       A0167_MASC_1_16Mar17_01.con   1.630000
# ...                                                          ...        ...
# 02      0       lw1        3.0       A0168_MASC_1_25Mar17_01.con  50.070000
#                            3.0       A0168_MASC_1_25Mar17_01.con  50.250000
#                            3.0       A0168_MASC_1_25Mar17_01.con  50.460000
#                            3.0       A0168_MASC_1_25Mar17_01.con  51.179999
#                            3.0       A0168_MASC_1_25Mar17_01.con  51.790000
#
#                                                        sound     word  \
# subject session story_name sound_id
# 01      0       lw1        0.0       stimuli/audio/lw1_0.wav     Tara
#                            0.0       stimuli/audio/lw1_0.wav    stood
#                            0.0       stimuli/audio/lw1_0.wav    stock
#                            0.0       stimuli/audio/lw1_0.wav    still
#                            0.0       stimuli/audio/lw1_0.wav  waiting
# ...                                                      ...      ...
# 02      0       lw1        3.0       stimuli/audio/lw1_3.wav      end
#                            3.0       stimuli/audio/lw1_3.wav      for
#                            3.0       stimuli/audio/lw1_3.wav  project
#                            3.0       stimuli/audio/lw1_3.wav      and
#                            3.0       stimuli/audio/lw1_3.wav  species
#
#                                      sequence_id condition  word_index  \
# subject session story_name sound_id
# 01      0       lw1        0.0               0.0  sentence         0.0
#                            0.0               0.0  sentence         1.0
#                            0.0               0.0  sentence         2.0
#                            0.0               0.0  sentence         3.0
#                            0.0               0.0  sentence         4.0
# ...                                          ...       ...         ...
# 02      0       lw1        3.0              52.0  sentence        15.0
#                            3.0              52.0  sentence        16.0
#                            3.0              52.0  sentence        18.0
#                            3.0              52.0  sentence        19.0
#                            3.0              52.0  sentence        22.0
#
#                                      speech_rate    voice  pronounced  \
# subject session story_name sound_id
# 01      0       lw1        0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
# ...                                          ...      ...         ...
# 02      0       lw1        3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#
#                                        onset  duration  value  sample  \
# subject session story_name sound_id
# 01      0       lw1        0.0        23.506      0.30    697   23506
#                            0.0        23.816      0.24    698   23816
#                            0.0        24.056      0.37    699   24056
#                            0.0        24.586      0.40    700   24586
#                            0.0        25.136      0.41    701   25136
# ...                                      ...       ...    ...     ...
# 02      0       lw1        3.0       356.763      0.17   3119  356763
#                            3.0       356.943      0.14   3120  356943
#                            3.0       357.153      0.58   3121  357153
#                            3.0       357.873      0.15   3122  357873
#                            3.0       358.483      0.34   3123  358483
#
#                                      onset_sound  onset_baselined
# subject session story_name sound_id
# 01      0       lw1        0.0            23.506             0.00
#                            0.0            23.506             0.31
#                            0.0            23.506             0.55
#                            0.0            23.506             1.08
#                            0.0            23.506             1.63
# ...                                          ...              ...
# 02      0       lw1        3.0           306.693            50.07
#                            3.0           306.693            50.25
#                            3.0           306.693            50.46
#                            3.0           306.693            51.18
#                            3.0           306.693            51.79
#
# [1336 rows x 19 columns]

# %%
# For each word presentation, get number of different onsets relative to sound onset.
# Should be 1 for everything.
num_unique_word_onsets = w.groupby(["story_name", "sequence_id", "word_index", "condition"]).apply(lambda xs: len(set(xs.onset_baselined)))
assert set(num_unique_word_onsets.values) == {1}

# %%
# And there should be N word presentations per word.
num_per_word_onset = w.groupby(["sound", "onset_baselined"]).size()
assert set(num_per_word_onset) == {len(presentations)}

# %%
# TODO check that these and the word lists are the same for all subjects/sessions
w.reset_index().set_index(["condition", "subject"]).loc["pseudo_words"].groupby("subject").head(10)
# Out:
#          session story_name  sound_id story  story_uid  kind  \
# subject
# 01             0        lw1       3.0   lw1        0.0  word
# 02             0        lw1       3.0   lw1        0.0  word
#
#                             meg_file  start                    sound word  \
# subject
# 01       A0167_MASC_1_16Mar17_01.con  33.23  stimuli/audio/lw1_3.wav   ro
# 02       A0168_MASC_1_25Mar17_01.con  33.23  stimuli/audio/lw1_3.wav   ro
#
#          ...  word_index  speech_rate    voice pronounced    onset  duration  \
# subject  ...
# 01       ...        20.0        205.0  Allison        1.0  344.257      0.15
# 02       ...        20.0        205.0  Allison        1.0  339.923      0.15
#
#          value  sample  onset_sound  onset_baselined
# subject
# 01        3071  344257      311.027            33.23
# 02        3071  339923      306.693            33.23
#
# [2 rows x 21 columns]

# %% [markdown]
# ## Check phonemes

# %%
p = all_presentations["phoneme"].set_index(index_key)
p["onset_sound"] = presentation_onsets
p["onset_baselined"] = (p.onset - p["onset_sound"]).round(4)
p
# Out:
#                                     story  story_uid     kind  \
# subject session story_name sound_id
# 01      0       lw1        0.0        lw1        0.0  phoneme
#                            0.0        lw1        0.0  phoneme
#                            0.0        lw1        0.0  phoneme
#                            0.0        lw1        0.0  phoneme
#                            0.0        lw1        0.0  phoneme
# ...                                   ...        ...      ...
# 02      0       lw1        3.0        lw1        0.0  phoneme
#                            3.0        lw1        0.0  phoneme
#                            3.0        lw1        0.0  phoneme
#                            3.0        lw1        0.0  phoneme
#                            3.0        lw1        0.0  phoneme
#
#                                                         meg_file  start  \
# subject session story_name sound_id
# 01      0       lw1        0.0       A0167_MASC_1_16Mar17_01.con   0.00
#                            0.0       A0167_MASC_1_16Mar17_01.con   0.08
#                            0.0       A0167_MASC_1_16Mar17_01.con   0.17
#                            0.0       A0167_MASC_1_16Mar17_01.con   0.24
#                            0.0       A0167_MASC_1_16Mar17_01.con   0.31
# ...                                                          ...    ...
# 02      0       lw1        3.0       A0168_MASC_1_25Mar17_01.con  51.85
#                            3.0       A0168_MASC_1_25Mar17_01.con  51.94
#                            3.0       A0168_MASC_1_25Mar17_01.con  52.03
#                            3.0       A0168_MASC_1_25Mar17_01.con  52.11
#                            3.0       A0168_MASC_1_25Mar17_01.con  52.12
#
#                                                        sound phoneme  \
# subject session story_name sound_id
# 01      0       lw1        0.0       stimuli/audio/lw1_0.wav     t_B
#                            0.0       stimuli/audio/lw1_0.wav    eh_I
#                            0.0       stimuli/audio/lw1_0.wav     r_I
#                            0.0       stimuli/audio/lw1_0.wav    ah_E
#                            0.0       stimuli/audio/lw1_0.wav     s_B
# ...                                                      ...     ...
# 02      0       lw1        3.0       stimuli/audio/lw1_3.wav     p_I
#                            3.0       stimuli/audio/lw1_3.wav    iy_I
#                            3.0       stimuli/audio/lw1_3.wav    sh_I
#                            3.0       stimuli/audio/lw1_3.wav    iy_I
#                            3.0       stimuli/audio/lw1_3.wav     z_E
#
#                                      sequence_id condition  word_index  \
# subject session story_name sound_id
# 01      0       lw1        0.0               0.0  sentence         0.0
#                            0.0               0.0  sentence         0.0
#                            0.0               0.0  sentence         0.0
#                            0.0               0.0  sentence         0.0
#                            0.0               0.0  sentence         1.0
# ...                                          ...       ...         ...
# 02      0       lw1        3.0              52.0  sentence        22.0
#                            3.0              52.0  sentence        22.0
#                            3.0              52.0  sentence        22.0
#                            3.0              52.0  sentence        22.0
#                            3.0              52.0  sentence        22.0
#
#                                      speech_rate    voice  pronounced  \
# subject session story_name sound_id
# 01      0       lw1        0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
#                            0.0             205.0  Allison         1.0
# ...                                          ...      ...         ...
# 02      0       lw1        3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#                            3.0             205.0  Allison         1.0
#
#                                        onset  duration  value  sample  \
# subject session story_name sound_id
# 01      0       lw1        0.0        23.506      0.08      5   23506
#                            0.0        23.586      0.09      6   23586
#                            0.0        23.676      0.07      7   23676
#                            0.0        23.746      0.06      8   23746
#                            0.0        23.816      0.06      9   23816
# ...                                      ...       ...    ...     ...
# 02      0       lw1        3.0       358.543      0.09   2962  358543
#                            3.0       358.633      0.09   2963  358633
#                            3.0       358.723      0.08   2964  358723
#                            3.0       358.803      0.01   2965  358803
#                            3.0       358.813      0.01   2966  358813
#
#                                      onset_sound  onset_baselined
# subject session story_name sound_id
# 01      0       lw1        0.0            23.506             0.00
#                            0.0            23.506             0.08
#                            0.0            23.506             0.17
#                            0.0            23.506             0.24
#                            0.0            23.506             0.31
# ...                                          ...              ...
# 02      0       lw1        3.0           306.693            51.85
#                            3.0           306.693            51.94
#                            3.0           306.693            52.03
#                            3.0           306.693            52.11
#                            3.0           306.693            52.12
#
# [4924 rows x 19 columns]

# %%
# For each phoneme presentation, get number of different onsets relative to sound onset.
# Should be 1 for everything.
num_unique_phoneme_onsets = p.groupby(["story_name", "sequence_id", "word_index", "condition", "value"]).apply(lambda xs: len(set(xs.onset_baselined)))
assert set(num_unique_phoneme_onsets.values) == {1}

# %%
# And there should be N presentations per phoneme.
num_per_phoneme_onset = w.groupby(["sound", "onset_baselined"]).size()
assert set(num_per_phoneme_onset) == {len(presentations)}

# %% [markdown]
# ## Build and save a canonical alignment

# %%
# Use first session as the canonical alignment. Arbitrary.
_, sound_sequence = next(iter(all_presentations["sound"].groupby(["subject", "session"])))
canonical_sound_sequence = sound_sequence[["story_name", "sound_id"]].drop_duplicates()

# %%
presentation_onsets = pd.merge(
    canonical_sound_sequence,
    all_presentations["sound"][["story_name", "sound_id", "subject", "session", "onset"]],
    how="left")

presentation_onsets
# Out:
#   story_name  sound_id subject  session    onset
# 0        lw1       0.0      01        0   23.506
# 1        lw1       0.0      02        0   18.389
# 2        lw1       1.0      01        0  127.185
# 3        lw1       1.0      02        0  121.868
# 4        lw1       2.0      01        0  210.048
# 5        lw1       2.0      02        0  207.648
# 6        lw1       3.0      01        0  311.027
# 7        lw1       3.0      02        0  306.693

# %%
presentation_onsets.to_csv(output_path)
